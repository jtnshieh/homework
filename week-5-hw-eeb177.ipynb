# %% [markdown]
# ## Homework 5

# %% [markdown]
# **Part 1**

# %% [markdown]
# 1. There are 194 families in this file.
# Shell command:
# cut -d "," -f 3 formatted.nature.csv | tail -n +4 | sort | uniq
# 2. The family that has the most species represented is Trochilidae.
# Shell command: cut -d "," -f 3 formatted.nature.csv | tr -c '[:alnum:]' '[\n*]'| sort | uniq -c | sort -nr | head -1
# 3. 60 families have only a single species in them.
# Shell command: cut -d "," -f 3 formatted.nature.csv | tr -c '[:alnum:]' '[\n*]'| sort | uniq -c | sort -nr | tail -60
# *Note: I tried out different numbers for tail to see at which number the families' species counts went from 1 to 2.
# 4. 239 families are present in the eBird data.
# Shell command: cut -d "," -f 8 newbirdfile.csv | tail -n +2 | sort | uniq
# 5. Please refer below:
# ```
# Shell command: cut -d "," -f 8 newbirdfile.csv | tail -n +2 | sort | uniq -c | sort -n
#       1 Anseranatidae (Magpie Goose)
#       1 Balaenicipitidae (Shoebill)
#       1 Donacobiidae (Donacobius)
#       1 Dromadidae (Crab Plover)
#       1 Dulidae (Palmchat)
#       1 Elachuridae (Spotted Elachura)
#       1 Eulacestomatidae (Ploughbill)
#       1 Eupetidae (Rail-babbler)
#       1 Eurypygidae (Sunbittern)
#       1 Hylocitreidae (Hylocitrea)
#       1 Hypocoliidae (Hypocolius)
#       1 Ibidorhynchidae (Ibisbill)
#       1 Ifritidae (Ifrita)
#       1 Leptosomidae (Cuckoo-Roller)
#       1 Notiomystidae (Stitchbird)
#       1 Opisthocomidae (Hoatzin)
#       1 Oxyruncidae (Sharpbill)
#       1 Panuridae (Bearded Reedling)
#       1 Pedionomidae (Plains-wanderer)
#       1 Peucedramidae (Olive Warbler)
#       1 Pityriaseidae (Bristlehead)
#       1 Pluvianellidae (Magellanic Plover)
#       1 Pluvianidae (Egyptian Plover)
#       1 Rhagologidae (Mottled Berryhunter)
#       1 Rhynochetidae (Kagu)
#       1 Sagittariidae (Secretary-bird)
#       1 Sapayoidae (Sapayoa)
#       1 Scopidae (Hamerkop)
#       1 Steatornithidae (Oilbird)
#       1 Tichodromidae (Wallcreeper)
#       1 Urocynchramidae (Przevalski's Pinktail)
#       2 Atrichornithidae (Scrub-birds)
#       2 Bucorvidae (Ground-Hornbills)
#       2 Cariamidae (Seriemas)
#       2 Chaetopidae (Rockjumpers)
#       2 Chionidae (Sheathbills)
#       2 Corcoracidae (White-winged Chough and Apostlebird)
#       2 Irenidae (Fairy-bluebirds)
#       2 Machaerirhynchidae (Boatbills)
#       2 Melampittidae (Melampittas)
#       2 Menuridae (Lyrebirds)
#       2 Paramythiidae (Tit Berrypecker and Crested Berrypecker)
#       2 Picathartidae (Rockfowl)
#       2 Semnornithidae (Toucan-Barbets)
#       3 Anhimidae (Screamers)
#       3 Aramidae (Limpkin)
#       3 Buphagidae (Oxpeckers)
#       3 Cnemophilidae (Satinbirds)
#       3 Dasyornithidae (Bristlebirds)
#       3 Heliornithidae (Finfoots)
#       3 Mesitornithidae (Mesites)
#       3 Mohouidae (Whiteheads)
#       3 Oreoicidae (Australo-Papuan Bellbirds)
#       3 Orthonychidae (Logrunners)
#       3 Rostratulidae (Painted-Snipes)
#       3 Struthionidae (Ostriches)
#       4 Acanthisittidae (New Zealand Wrens)
#       4 Anhingidae (Anhingas)
#       4 Bombycillidae (Waxwings)
#       4 Casuariidae (Cassowaries and Emu)
#       4 Falcunculidae (Shrike-tit)
#       4 Hyliotidae (Hyliotas)
#       4 Melanopareiidae (Crescentchests)
#       4 Nicatoridae (Nicators)
#       4 Ptiliogonatidae (Silky-flycatchers)
#       4 Rheidae (Rheas)
#       4 Strigopidae (New Zealand Parrots)
#       4 Thinocoridae (Seedsnipes)
#       5
#       5 Aegithinidae (Ioras)
#       5 Brachypteraciidae (Ground-Rollers)
#       5 Callaeidae (Wattlebirds)
#       5 Hemiprocnidae (Treeswifts)
#       5 Mohoidae (Hawaiian Honeyeaters)
#       5 Pandionidae (Osprey)
#       5 Philepittidae (Asities)
#       5 Pomatostomidae (Pseudo-Babblers)
#       5 Promeropidae (Sugarbirds)
#       5 Psophodidae (Whipbirds and Wedgebills)
#       5 Upupidae (Hoopoes)
#       6 Fregatidae (Frigatebirds)
#       6 Todidae (Todies)
#       7 Apterygidae (Kiwis)
#       7 Coliidae (Mousebirds)
#       7 Pnoepygidae (Cupwings)
#       8 Gaviidae (Loons)
#       8 Neosittidae (Sittellas)
#       8 Phoenicopteridae (Flamingos)
#       9 Calcariidae (Longspurs and Snow Buntings)
#       9 Climacteridae (Australasian Treecreepers)
#      10 Calyptomenidae (African and Green Broadbills)
#      10 Cinclidae (Dippers)
#      10 Nyctibiidae (Potoos)
#      11 Bernieridae (Malagasy Warblers)
#      11 Burhinidae (Thick-knees)
#      11 Eurylaimidae (Asian and Grauer's Broadbills)
#      11 Phaethontidae (Tropicbirds)
#      11 Psophiidae (Trumpeters)
#      11 Stenostiridae (Fairy Flycatchers)
#      12 Cathartidae (New World Vultures)
#      12 Melanocharitidae (Berrypeckers and Longbills)
#      12 Pardalotidae (Pardalotes)
#      13 Chloropseidae (Leafbirds)
#      13 Conopophagidae (Gnateaters)
#      13 Jacanidae (Jacanas)
#      13 Pelecanidae (Pelicans)
#      13 Phoeniculidae (Woodhoopoes and Scimitar-bills)
#      13 Regulidae (Kinglets)
#      14 Aegothelidae (Owlet-nightjars)
#      14 Artamidae (Woodswallows)
#      14 Cinclosomatidae (Quail-thrushes and Jewel-babblers)
#      14 Prunellidae (Accentors)
#      15 Numididae (Guineafowl)
#      15 Sarothruridae (Flufftails)
#      16 Haematopodidae (Oystercatchers)
#      16 Remizidae (Penduline-Tits)
#      16 Stercorariidae (Skuas and Jaegers)
#      17 Formicariidae (Antthrushes)
#      18 Capitonidae (New World Barbets)
#      18 Coraciidae (Rollers)
#      19 Certhiidae (Treecreepers)
#      19 Recurvirostridae (Stilts and Avocets)
#      19 Turnicidae (Buttonquail)
#      20 Indicatoridae (Honeyguides)
#      21 Momotidae (Motmots)
#      21 Spheniscidae (Penguins)
#      21 Sulidae (Boobies and Gannets)
#      23 Aegithalidae (Long-tailed Tits)
#      23 Galbulidae (Jacamars)
#      23 Glareolidae (Pratincoles and Coursers)
#      23 Gruidae (Cranes)
#      23 Megapodiidae (Megapodes)
#      23 Podargidae (Frogmouths)
#      23 Viduidae (Indigobirds)
#      24 Pteroclidae (Sandgrouse)
#      25 Ciconiidae (Storks)
#      25 Macrosphenidae (African Warblers)
#      26 Cacatuidae (Cockatoos)
#      26 Cracticidae (Bellmagpies and Allies)
#      28 Ptilonorhynchidae (Bowerbirds)
#      30 Polioptilidae (Gnatcatchers)
#      31 Podicipedidae (Grebes)
#      33 Diomedeidae (Albatrosses)
#      33 Meropidae (Bee-eaters)
#      34 Otididae (Bustards)
#      35 Tytonidae (Barn-Owls)
#      37 Sittidae (Nuthatches)
#      40 "Alcidae (Auks
#      40 Dicruridae (Drongos)
#      40 Maluridae (Fairywrens)
#      41 Musophagidae (Turacos)
#      42 Cettiidae (Bush-Warblers and Allies)
#      42 Megalaimidae (Asian Barbets)
#      44 Threskiornithidae (Ibises and Spoonbills)
#      44 Tityridae (Tityras and Allies)
#      45 Paradisaeidae (Birds-of-Paradise)
#      45 Platysteiridae (Wattle-eyes and Batises)
#      46 Mimidae (Mockingbirds and Thrashers)
#      46 Oriolidae (Old World Orioles)
#      46 "Paradoxornithidae (Parrotbills
#      47 Sylviidae (Sylviid Warblers)
#      48 Bucconidae (Puffbirds)
#      50 Hydrobatidae (Storm-Petrels)
#      50 Odontophoridae (New World Quail)
#      54 "Vangidae (Vangas
#      55 Passeridae (Old World Sparrows)
#      56 Phalacrocoracidae (Cormorants and Shags)
#      57 Dicaeidae (Flowerpeckers)
#      57 Tinamidae (Tinamous)
#      58 Petroicidae (Australasian Robins)
#      59 Laniidae (Shrikes)
#      59 Pittidae (Pittas)
#      61 Trogonidae (Trogons)
#      64 Lybiidae (African Barbets)
#      64 Ramphastidae (Toucans)
#      67 Pipridae (Manakins)
#      67 "Timaliidae (Tree-Babblers
#      70 Pellorneidae (Ground Babblers and Allies)
#      71 Pachycephalidae (Whistlers and Allies)
#      72 "Cracidae (Guans
#      72 Malaconotidae (Bushshrikes and Allies)
#      74 Bucerotidae (Hornbills)
#      74 Grallariidae (Antpittas)
#      75 Rhinocryptidae (Tapaculos)
#      76 Acanthizidae (Thornbills and Allies)
#      76 Cotingidae (Cotingas)
#      76 Locustellidae (Grassbirds and Allies)
#      80 Acrocephalidae (Reed-Warblers and Allies)
#      86 Rhipiduridae (Fantails)
#      90 Charadriidae (Plovers and Lapwings)
#      93 Cardinalidae (Cardinals and Allies)
#      98 "Paridae (Tits
#     108 "Vireonidae (Vireos
#     109 Falconidae (Falcons and Caracaras)
#     111 Campephagidae (Cuckooshrikes)
#     119 Phylloscopidae (Leaf Warblers)
#     124 Caprimulgidae (Nightjars and Allies)
#     126 "Ardeidae (Herons
#     130 Motacillidae (Wagtails and Pipits)
#     136 Monarchidae (Monarch Flycatchers)
#     144 Procellariidae (Shearwaters and Petrels)
#     146 Hirundinidae (Swallows)
#     147 Sturnidae (Starlings)
#     147 "Zosteropidae (White-eyes
#     148 Alaudidae (Larks)
#     152 Apodidae (Swifts)
#     154 Ploceidae (Weavers and Allies)
#     158 Scolopacidae (Sandpipers and Allies)
#     161 Alcedinidae (Kingfishers)
#     165 Troglodytidae (Wrens)
#     166 Icteridae (Troupials and Allies)
#     171 Leiothrichidae (Laughingthrushes and Allies)
#     176 Estrildidae (Waxbills and Allies)
#     190 "Corvidae (Crows
#     190 Nectariniidae (Sunbirds and Spiderhunters)
#     200 Pycnonotidae (Bulbuls)
#     203 "Rallidae (Rails
#     206 Cuculidae (Cuckoos)
#     208 Meliphagidae (Honeyeaters)
#     209 "Laridae (Gulls
#     222 Cisticolidae (Cisticolas and Allies)
#     226 Psittaculidae (Old World Parrots)
#     228 Parulidae (New World Warblers)
#     240 "Phasianidae (Pheasants
#     251 Psittacidae (New World and African Parrots)
#     295 Turdidae (Thrushes and Allies)
#     298 Thamnophilidae (Typical Antbirds)
#     318 Emberizidae (Buntings and New World Sparrows)
#     318 Strigidae (Owls)
#     325 "Fringillidae (Finches
#     364 "Anatidae (Ducks
#     370 Picidae (Woodpeckers)
#     386 "Accipitridae (Hawks
#     425 Columbidae (Pigeons and Doves)
#     452 Furnariidae (Ovenbirds and Woodcreepers)
#     457 Muscicapidae (Old World Flycatchers)
#     472 Trochilidae (Hummingbirds)
#     505 Thraupidae (Tanagers and Allies)
#     617 Tyrannidae (Tyrant Flycatchers)
# ```

# %%
nature_file = open("/home/eeb177-student/Desktop formatted.nature.csv")
file_contents = nature_file.read()
split_file  = file_contents.split(",")

# %%
import csv
reader = csv.reader(open("/home/eeb177-student/Desktop/eeb-177/homework/naturecolumns1and3.csv","r"))
nature_dictionary = {}
for row in reader:
    k, v = row
    nature_dictionary[k] = v

print(nature_dictionary)
# Out:
# {'Entomyzon_cyanotis': 'Meliphagidae', 'Callaeas_cinereus': 'Callaeatidae', 'Microdynamis_parva': 'Cuculidae', 'Himantopus_himantopus': 'Recurvirostridae', 'Tyranneutes_stolzmanni': 'Pipridae', 'Cettia_diphone': 'Sylviidae', 'Gymnomystax_mexicanus': 'Icteridae', 'Phainopepla_nitens': 'Bombycillidae', 'Aviceda_jerdoni': 'Accipitridae', 'Acanthisitta_chloris': 'Acanthisittidae', 'Hemithraupis_ruficapilla': 'Thraupidae', 'Pseudeos_fuscata': 'Psittacidae', 'Henicopernis_longicauda': 'Accipitridae', 'Metopidius_indicus': 'Jacanidae', 'Masius_chrysopterus': 'Pipridae', 'Certhiaxis_cinnamomeus': 'Furnariidae', 'Ilicura_militaris': 'Pipridae', 'Amblycercus_holosericeus': 'Icteridae', 'Monasa_nigrifrons': 'Bucconidae', 'Corapipo_gutturalis': 'Pipridae', 'Querula_purpurata': 'Cotingidae', 'Heteromunia_pectoralis': 'Estrildidae', 'Pycnoptilus_floccosus': 'Acanthizidae', 'Phylloscopus_canariensis': 'Sylviidae', 'Salpornis_spilonotus': 'Certhiidae', 'Lerwa_lerwa': 'Phasianidae', 'Compsospiza_garleppi': 'Thraupidae', 'Daption_capense': 'Procellariidae', 'Leptoptilos_javanicus': 'Ciconiidae', 'Ptychoramphus_aleuticus': 'Alcidae', 'Pygoscelis_antarcticus': 'Spheniscidae', 'Calyptocichla_serina': 'Pycnonotidae', 'Melozone_biarcuata': 'Emberizidae', 'Urosticte_benjamini': 'Trochilidae', 'Lampropsar_tanagrinus': 'Icteridae', 'Rallina_fasciata': 'Rallidae', 'Lullula_arborea': 'Alaudidae', 'Cotinga_amabilis': 'Cotingidae', 'Hodgsonius_phaenicuroides': 'Muscicapidae', 'Phoenicircus_nigricollis': 'Cotingidae', 'Parabuteo_unicinctus': 'Accipitridae', 'Carpococcyx_radiatus': 'Cuculidae', 'Branta_bernicla': 'Anatidae', 'Ramsayornis_modestus': 'Meliphagidae', 'Bubulcus_ibis': 'Ardeidae', 'Prunella_himalayana': 'Prunellidae', 'Petrophassa_albipennis': 'Columbidae', 'Burhinus_superciliaris': 'Burhinidae', 'Prodotiscus_insignis': 'Indicatoridae', 'Butorides_striata': 'Ardeidae', 'Setornis_criniger': 'Pycnonotidae', 'Struthio_camelus': 'Struthionidae', 'Rhabdornis_mystacalis': 'Rhabdornithidae', 'Chloephaga_melanoptera': 'Anatidae', 'Biziura_lobata': 'Anatidae', 'Anurophasis_monorthonyx': 'Phasianidae', 'Merops_nubicoides': 'Meropidae', 'Liocichla_steerii': 'Timaliidae', 'Oxyura_jamaicensis': 'Anatidae', 'Phylidonyris_pyrrhopterus': 'Meliphagidae', 'Harpyhaliaetus_solitarius': 'Accipitridae', 'Creatophora_cinerea': 'Sturnidae', 'Crypsirina_cucullata': 'Corvidae', 'Momotus_momota': 'Momotidae', 'Abroscopus_schisticeps': 'Sylviidae', 'Xenocopsychus_ansorgei': 'Muscicapidae', 'Heteromirafra_ruddi': 'Alaudidae', 'Clytospiza_monteiri': 'Estrildidae', 'Myiopagis_gaimardii': 'Tyrannidae', 'Dendragapus_obscurus': 'Phasianidae', 'Thaumastura_cora': 'Trochilidae', 'Oreolais_pulchra': 'Cisticolidae', 'Doryfera_johannae': 'Trochilidae', 'Columba_bollii': 'Columbidae', 'Amytornis_barbatus': 'Maluridae', 'Brachygalba_salmoni': 'Galbulidae', 'Pseudoseisura_cristata': 'Furnariidae', 'Xanthocephalus_xanthocephalus': 'Icteridae', 'Treron_calvus': 'Columbidae', 'Struthidea_cinerea': 'Corcoracidae', 'Teretistris_fernandinae': 'Parulidae', 'Temnurus_temnurus': 'Corvidae', 'Myrtis_fanny': 'Trochilidae', 'Xema_sabini': 'Laridae', 'Podager_nacunda': 'Caprimulgidae', 'Orthopsittaca_manilata': 'Psittacidae', 'Aegypius_monachus': 'Accipitridae', 'Cnemarchus_erythropygius': 'Tyrannidae', 'Chalcophaps_indica': 'Columbidae', 'Rhodothraupis_celaeno': 'Cardinalidae', 'Oreophasis_derbianus': 'Cracidae', 'Leptasthenura_platensis': 'Furnariidae', 'Laterallus_melanophaius': 'Rallidae', 'Copsychus_albospecularis': 'Muscicapidae', 'Cinnycerthia_unirufa': 'Troglodytidae', 'Rhyacornis_fuliginosa': 'Muscicapidae', 'Campylorhamphus_pucherani': 'Dendrocolaptidae', 'Microligea_palustris': 'Parulidae', 'Molothrus_oryzivorus': 'Icteridae', 'Bernieria_zosterops': 'Sylviidae', 'Curaeus_curaeus': 'Icteridae', 'Lafresnaya_lafresnayi': 'Trochilidae', 'Mandingoa_nitidula': 'Estrildidae', 'Liosceles_thoracicus': 'Rhinocryptidae', 'Aeronautes_andecolus': 'Apodidae', 'Bleda_notatus': 'Pycnonotidae', 'Muscicapel ...

# %%
import csv
reader = csv.reader(open("/home/eeb177-student/Desktop/eeb-177/homework/birdcolumns3and8.csv","r"))
bird_dictionary = {}
for row in reader:
    k, v = row
    bird_dictionary[k] = v

print(bird_dictionary)
# Out:
# {'gbwwre1': 'Troglodytidae (Wrens)', 'yehpar1': 'Psittacidae (New World and African Parrots)', 'masant1': 'Grallariidae (Antpittas)', 'flabul3': 'Pycnonotidae (Bulbuls)', 'sogshr2': 'Laniidae (Shrikes)', 'rutatt1': 'Tyrannidae (Tyrant Flycatchers)', 'grnimp2': 'Columbidae (Pigeons and Doves)', 'slagna1': 'Conopophagidae (Gnateaters)', 'wfsowl2': 'Strigidae (Owls)', 'coleto1': 'Sturnidae (Starlings)', 'pasfly': 'Tyrannidae (Tyrant Flycatchers)', 'yebori1': 'Icteridae (Troupials and Allies)', 'ruecha1': 'Muscicapidae (Old World Flycatchers)', 'commoo1': 'Rallidae (Rails\ncommoo,Rallidae (Rails', 'rdjant1': 'Thamnophilidae (Typical Antbirds)', 'asecuc1': 'Cuculidae (Cuckoos)', 'ywcpar': 'Psittacidae (New World and African Parrots)', 'wfqdov': 'Columbidae (Pigeons and Doves)', 'rubpic1': 'Picidae (Woodpeckers)', 'lobpip8': 'Motacillidae (Wagtails and Pipits)', 'waicis3': 'Cisticolidae (Cisticolas and Allies)', 'yebspa1': 'Emberizidae (Buntings and New World Sparrows)', 'scbant4': 'Thamnophilidae (Typical Antbirds)', 'batsee1': 'Thraupidae (Tanagers and Allies)', 'antvir1': 'Thamnophilidae (Typical Antbirds)', 'blhsap1': 'Trochilidae (Hummingbirds)', 'bltwhi1': 'Pachycephalidae (Whistlers and Allies)', 'ligwoo3': 'Picidae (Woodpeckers)', 'herthr2': 'Turdidae (Thrushes and Allies)', 'meapar': 'Psittacidae (New World and African Parrots)', 'blhbat1': 'Platysteiridae (Wattle-eyes and Batises)', 'masowl2': 'Strigidae (Owls)', 'pepcis3': 'Cisticolidae (Cisticolas and Allies)', 'y00815': 'Phylloscopidae (Leaf Warblers)', 'cibkin1': 'Alcedinidae (Kingfishers)', 'orisal1': 'Thraupidae (Tanagers and Allies)', 'whwfan1': 'Rhipiduridae (Fantails)', 'rossta2': 'Sturnidae (Starlings)', 'stelio1': 'Leiothrichidae (Laughingthrushes and Allies)', 'thlant3': 'Grallariidae (Antpittas)', 'hydrop1': 'Caprimulgidae (Nightjars and Allies)', 'bolspi1': 'Furnariidae (Ovenbirds and Woodcreepers)', 'lesfla1': 'Phoenicopteridae (Flamingos)', 'sicant1': 'Thamnophilidae (Typical Antbirds)', 'capbat4': 'Platysteiridae (Wattle-eyes and Batises)', 'pabspi1': 'Furnariidae (Ovenbirds and Woodcreepers)', 'socfly2': 'Tyrannidae (Tyrant Flycatchers)', 'stopar2': 'Odontophoridae (New World Quail)', 'brgdov1': 'Columbidae (Pigeons and Doves)', 'y00650': 'Phylloscopidae (Leaf Warblers)', 'blcswa1': 'Hirundinidae (Swallows)', 'bonpar1': 'Psittacidae (New World and African Parrots)', 'grwpel1': 'Pelecanidae (Pelicans)', 'lipfly1': 'Muscicapidae (Old World Flycatchers)', 'plcsta': 'Trochilidae (Hummingbirds)', 'vardwk14': 'Alcedinidae (Kingfishers)', 'murpet': 'Procellariidae (Shearwaters and Petrels)', 'olifin1': 'Emberizidae (Buntings and New World Sparrows)', 'swfgle': 'Furnariidae (Ovenbirds and Woodcreepers)', 'blbgra1': 'Thraupidae (Tanagers and Allies)', 'pygmy-1': 'Psittaculidae (Old World Parrots)', 'pogpig1': 'Columbidae (Pigeons and Doves)', 'megala1': 'Megalaimidae (Asian Barbets)', 'rutfog1': 'Furnariidae (Ovenbirds and Woodcreepers)', 'eurjay8': 'Corvidae (Crows\neurjay9,Corvidae (Crows', 'blabaz1': 'Accipitridae (Hawks\nrehvul1,Accipitridae (Hawks', 'wallcr1': 'Tichodromidae (Wallcreeper)', 'mouwre2': 'Troglodytidae (Wrens)', 'bonpig1': 'Columbidae (Pigeons and Doves)', 'chafly5': 'Muscicapidae (Old World Flycatchers)', 'laplon': 'Calcariidae (Longspurs and Snow Buntings)', 'azchum1': 'Trochilidae (Hummingbirds)', 'blfapa1': 'Cisticolidae (Cisticolas and Allies)', 'colinc2': 'Trochilidae (Hummingbirds)', 'venili1': 'Picidae (Woodpeckers)', 'itonig1': 'Caprimulgidae (Nightjars and Allies)', 'bufowl1': 'Strigidae (Owls)', 'thornb1': 'Acanthizidae (Thornbills and Allies)', 'swahaw': 'Accipitridae (Hawks\ngalhaw1,Accipitridae (Hawks', 'whtnee': 'Apodidae (Swifts)', 'leaf-l1': 'Pycnonotidae (Bulbuls)', 'buntin': 'Cardinalidae (Cardinals and Allies)', 'herpet2': 'Procellariidae (Shearwaters and Petrels)', 'blcbar1': 'Lybiidae (African Barbets)', 'x00642': 'Paridae (Tits\nblctit4,Paridae (Tits', 'galpen1': 'Spheniscidae (Penguins)', 'wemcha1': 'Cracidae (Guans\nchac ...
